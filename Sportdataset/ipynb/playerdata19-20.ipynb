# %%
#passing
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# Set the URL of the website you want to scrape
url = "https://fbref.com/en/comps/9/2019-2020/stats/2019-2020-Premier-League-Stats"

# Set the path to your Chrome WebDriver executable
service = Service(executable_path="/Users/morgan/Desktop/chromedriver-mac-arm64/chromedriver")
# Create a Chrome WebDriver instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

# Navigate to the URL
driver.get(url)

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the table containing player stats
stats_table = driver.find_element(By.ID, "stats_standard")

# Find all rows in the table
rows = stats_table.find_elements(By.TAG_NAME, "tr")

# Initialize lists to store data
player_names = []
MP = []
Gls = []
AST = []
CRDY = []
CRDR = []



# Loop through the rows and extract data
for row in rows[1:]:  # Skip the header row
    columns = row.find_elements(By.TAG_NAME, "td")
    if len(columns) >= 18:
        player_name = columns[0].text
        Match = columns[6].text
        goals = columns[10].text
        assist = columns[11].text
        yellow = columns[16].text
        red = columns[17].text


        player_names.append(player_name)
        MP.append(Match)
        Gls.append(goals)
        AST.append(assist)
        CRDY.append(yellow)
        CRDR.append(red)


# Close the Chrome WebDriver
driver.quit()

# Print or process the collected data as needed
for i in range(len(player_names)):
    print(f"Player Name: {player_names[i]}, mp: {MP[i]}, Gls: {Gls[i]}, Ast: {AST[i]}, CRDY: {CRDY[i]}, CRDR: {CRDR[i]}")
# Out:
# Player Name: Patrick van Aanholt, mp: 29, Gls: 3, Ast: 2, CRDY: 0, CRDR: 0
# Player Name: Max Aarons, mp: 36, Gls: 0, Ast: 1, CRDY: 7, CRDR: 0
# Player Name: Tammy Abraham, mp: 34, Gls: 15, Ast: 3, CRDY: 2, CRDR: 0
# Player Name: Che Adams, mp: 30, Gls: 4, Ast: 2, CRDY: 0, CRDR: 0
# Player Name: Adrián, mp: 11, Gls: 0, Ast: 0, CRDY: 1, CRDR: 0
# Player Name: Sergio Agüero, mp: 24, Gls: 16, Ast: 3, CRDY: 1, CRDR: 0
# Player Name: Albian Ajeti, mp: 9, Gls: 0, Ast: 0, CRDY: 0, CRDR: 0
# Player Name: Nathan Aké, mp: 29, Gls: 2, Ast: 2, CRDY: 2, CRDR: 0
# Player Name: Marc Albrighton, mp: 20, Gls: 0, Ast: 3, CRDY: 2, CRDR: 0
# Player Name: Toby Alderweireld, mp: 33, Gls: 2, Ast: 2, CRDY: 7, CRDR: 0
# Player Name: Trent Alexander-Arnold, mp: 38, Gls: 4, Ast: 13, CRDY: 5, CRDR: 0
# Player Name: Alisson, mp: 29, Gls: 0, Ast: 1, CRDY: 0, CRDR: 1
# Player Name: Dele Alli, mp: 25, Gls: 8, Ast: 4, CRDY: 2, CRDR: 0
# Player Name: Miguel Almirón, mp: 36, Gls: 4, Ast: 2, CRDY: 5, CRDR: 0
# ...

# %%
#passing
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# Set the URL of the website you want to scrape
url = "https://fbref.com/en/comps/9/2019-2020/passing/2019-2020-Premier-League-Stats"

# Set the path to your Chrome WebDriver executable
service = Service(executable_path="/Users/morgan/Desktop/chromedriver-mac-arm64/chromedriver")
# Create a Chrome WebDriver instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

# Navigate to the URL
driver.get(url)

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the table containing player stats
stats_table = driver.find_element(By.ID, "stats_passing")

# Find all rows in the table
rows = stats_table.find_elements(By.TAG_NAME, "tr")

# Initialize lists to store data
player_names = []
cmp = []
Att = []



# Loop through the rows and extract data
for row in rows[1:]:  # Skip the header row
    columns = row.find_elements(By.TAG_NAME, "td")
    if len(columns) >= 18:
        player_name = columns[0].text
        PC = columns[7].text
        PA = columns[8].text


        player_names.append(player_name)
        cmp.append(PC)
        Att.append(PA)


# Close the Chrome WebDriver
driver.quit()

# Print or process the collected data as needed
for i in range(len(player_names)):
    print(f"Player Name: {player_names[i]}, Cmp: {cmp[i]}, Att: {[i]}")
# Out:
# Player Name: Patrick van Aanholt, Cmp: 1241, Att: [0]
# Player Name: Max Aarons, Cmp: 1332, Att: [1]
# Player Name: Tammy Abraham, Cmp: 275, Att: [2]
# Player Name: Che Adams, Cmp: 162, Att: [3]
# Player Name: Adrián, Cmp: 238, Att: [4]
# Player Name: Sergio Agüero, Cmp: 286, Att: [5]
# Player Name: Albian Ajeti, Cmp: 12, Att: [6]
# Player Name: Nathan Aké, Cmp: 1079, Att: [7]
# Player Name: Marc Albrighton, Cmp: 339, Att: [8]
# Player Name: Toby Alderweireld, Cmp: 1630, Att: [9]
# Player Name: Trent Alexander-Arnold, Cmp: 2278, Att: [10]
# Player Name: Alisson, Cmp: 820, Att: [11]
# Player Name: Dele Alli, Cmp: 632, Att: [12]
# Player Name: Miguel Almirón, Cmp: 681, Att: [13]
# Player Name: Marcos Alonso, Cmp: 916, Att: [14]
# Player Name: Steven Alzate, Cmp: 556, Att: [15]
# Player Name: Ibrahim Amadou, Cmp: 324, Att: [16]
# Player Name: Felipe Anderson, Cmp: 727, Att: [17]
# Player Name: Florin Andone, Cmp: 7, Att: [18]
# Player Name: Angeliño, Cmp: 333, Att: [19]
# ...

# %%
#shooting
from selenium import webdriver
from selenium.webdriver.common.by import By

# Set the URL of the website you want to scrape
url = "https://fbref.com/en/comps/9/2019-2020/shooting/2019-2020-Premier-League-Stats"

# Set the path to your Chrome WebDriver executable
service = Service(executable_path="/Users/morgan/Desktop/chromedriver-mac-arm64/chromedriver")
# Create a Chrome WebDriver instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

# Navigate to the URL
driver.get(url)

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the table containing player stats
stats_table = driver.find_element(By.ID, "stats_shooting")

# Find all rows in the table
rows = stats_table.find_elements(By.TAG_NAME, "tr")

# Initialize lists to store data
player_names = []
Sh = []
SoT = []
Dist = []
FK = []



# Loop through the rows and extract data
for row in rows[1:]:  # Skip the header row
    columns = row.find_elements(By.TAG_NAME, "td")
    if len(columns) >= 18:
        player_name = columns[0].text
        shot = columns[8].text
        sotarget = columns[9].text
        distance = columns[15].text
        freekick = columns[16].text


        player_names.append(player_name)
        Sh.append(shot)
        SoT.append(sotarget)
        Dist.append(distance)
        FK.append(freekick)


# Close the Chrome WebDriver
driver.quit()

# Print or process the collected data as needed
for i in range(len(player_names)):
    print(f"Player Name: {player_names[i]}, shot: {Sh[i]}, SOT: {SoT[i]}, Dist: {Dist[i]}, FK: {FK[i]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/morgan/Desktop/sportML project/data scraping/playerdata19-20.ipynb 单元格 3 line <cell line: 36>()
#      <a href='vscode-notebook-cell:/Users/morgan/Desktop/sportML%20project/data%20scraping/playerdata19-20.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a> for row in rows[1:]:  # Skip the header row
#      <a href='vscode-notebook-cell:/Users/morgan/Desktop/sportML%20project/data%20scraping/playerdata19-20.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a>     columns = row.find_elements(By.TAG_NAME, "td")
# ---> <a href='vscode-notebook-cell:/Users/morgan/Desktop/sportML%20project/data%20scraping/playerdata19-20.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>     if len(columns) >= 18:
# ...

# %%
#standard
from selenium import webdriver
from selenium.webdriver.common.by import By

# Set the URL of the website you want to scrape
url = "https://fbref.com/en/comps/9/2019-2020/defense/2019-2020-Premier-League-Stats"

# Set the path to your Chrome WebDriver executable
service = Service(executable_path="/Users/morgan/Desktop/chromedriver-mac-arm64/chromedriver")
# Create a Chrome WebDriver instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

# Navigate to the URL
driver.get(url)

# Wait for the page to load (you may need to adjust the wait 
# time)
driver.implicitly_wait(10)

# Find the table containing player stats
stats_table = driver.find_element(By.ID, "stats_defense")

# Find all rows in the table
rows = stats_table.find_elements(By.TAG_NAME, "tr")

# Initialize lists to store data
player_names = []
TKL=[]
Dribbles_c=[]
Block=[]



# Loop through the rows and extract data
for row in rows[1:]:  # Skip the header row
    columns = row.find_elements(By.TAG_NAME, "td")
    if len(columns) >= 18:
        player_name = columns[0].text
        tackles = columns[7].text
        dri_challenge = columns[13].text
        nblock = columns[16].text


        player_names.append(player_name)
        TKL.append(tackles)
        Dribbles_c.append(dri_challenge)
        Block.append(nblock)


# Close the Chrome WebDriver
driver.quit()

# Print or process the collected data as needed
for i in range(len(player_names)):
    print(f"Player Name: {player_names[i]}, TKL: {TKL[i]}, Dribbles: {Dribbles_c[i]}, Block: {Block[i]}")
# Out:
# Player Name: Patrick van Aanholt, TKL: 43, Dribbles: 50, Block: 31
# Player Name: Max Aarons, TKL: 48, Dribbles: 36, Block: 46
# Player Name: Tammy Abraham, TKL: 8, Dribbles: 14, Block: 20
# Player Name: Che Adams, TKL: 6, Dribbles: 4, Block: 9
# Player Name: Adrián, TKL: 1, Dribbles: 1, Block: 0
# Player Name: Sergio Agüero, TKL: 7, Dribbles: 8, Block: 9
# Player Name: Albian Ajeti, TKL: 1, Dribbles: 0, Block: 0
# Player Name: Nathan Aké, TKL: 31, Dribbles: 23, Block: 40
# Player Name: Marc Albrighton, TKL: 24, Dribbles: 30, Block: 19
# Player Name: Toby Alderweireld, TKL: 40, Dribbles: 24, Block: 48
# Player Name: Trent Alexander-Arnold, TKL: 55, Dribbles: 78, Block: 27
# Player Name: Alisson, TKL: 0, Dribbles: 2, Block: 0
# Player Name: Dele Alli, TKL: 34, Dribbles: 37, Block: 35
# Player Name: Miguel Almirón, TKL: 60, Dribbles: 52, Block: 25
# Player Name: Marcos Alonso, TKL: 28, Dribbles: 33, Block: 18
# Player Name: Steven Alzate, TKL: 33, Dribbles: 27, Block: 18
# ...

# %%
#standard
from selenium import webdriver
from selenium.webdriver.common.by import By

# Set the URL of the website you want to scrape
url = "https://fbref.com/en/comps/9/2019-2020/possession/2019-2020-Premier-League-Stats"

# Set the path to your Chrome WebDriver executable
service = Service(executable_path="/Users/morgan/Desktop/chromedriver-mac-arm64/chromedriver")
# Create a Chrome WebDriver instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

# Navigate to the URL
driver.get(url)

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the table containing player stats
stats_table = driver.find_element(By.ID, "stats_possession")

# Find all rows in the table
rows = stats_table.find_elements(By.TAG_NAME, "tr")

# Initialize lists to store data
player_names = []
Touches=[]
Attempted=[]
Succ=[]
Carries=[]
Rec=[]



# Loop through the rows and extract data
for row in rows[1:]:  # Skip the header row
    columns = row.find_elements(By.TAG_NAME, "td")
    if len(columns) >= 28:
        player_name = columns[0].text
        touch = columns[7].text
        attp = columns[14].text
        success = columns[15].text
        car = columns[19].text
        receiving = columns[27].text


        player_names.append(player_name)
        Touches.append(touch)
        Attempted.append(attp)
        Succ.append(success)
        Carries.append(car)
        Rec.append(receiving)


# Close the Chrome WebDriver
driver.quit()

# Print or process the collected data as needed
for i in range(len(player_names)):
    print(f"Player Name: {player_names[i]}, Touches: {Touches[i]}, Attp: {Attempted[i]}, Succ: {Succ[i]}, Carries: {Carries[i]}, Receiving: {Rec[i]}")
# Out:
# Player Name: Patrick van Aanholt, Touches: 1870, Attp: 38, Succ: 16, Carries: 830, Receiving: 994
# Player Name: Max Aarons, Touches: 2144, Attp: 99, Succ: 48, Carries: 1259, Receiving: 1253
# Player Name: Tammy Abraham, Touches: 722, Attp: 35, Succ: 16, Carries: 333, Receiving: 479
# Player Name: Che Adams, Touches: 418, Attp: 25, Succ: 18, Carries: 232, Receiving: 298
# Player Name: Adrián, Touches: 331, Attp: 0, Succ: 0, Carries: 193, Receiving: 152
# Player Name: Sergio Agüero, Touches: 544, Attp: 40, Succ: 24, Carries: 405, Receiving: 436
# Player Name: Albian Ajeti, Touches: 28, Attp: 2, Succ: 0, Carries: 17, Receiving: 22
# Player Name: Nathan Aké, Touches: 1557, Attp: 3, Succ: 3, Carries: 958, Receiving: 922
# Player Name: Marc Albrighton, Touches: 618, Attp: 33, Succ: 14, Carries: 393, Receiving: 423
# Player Name: Toby Alderweireld, Touches: 2349, Attp: 1, Succ: 0, Carries: 1460, Receiving: 1566
# ...

# %%
import pandas as pd
df = {
    "Player Name": player_names,
    "MP":MP,
    "Gls": Gls,
    "Ast": AST,
    "CRDY": CRDY,
    "CRDR": CRDR, 
    "CMP":cmp,   
    "Att":Att,
    "Sh":Sh,
    "SoT":SoT,
    "Dist":Dist,
    "FK":FK,
    "TKL":TKL,
    "Dribbles":Dribbles_c,
    "Blocks":Block,
    "Touches":Touches,
    "Attp":Attempted,
    "Succ":Succ,
    "Carries":Carries,
    "Receiving":Rec
      
}
df1=pd.DataFrame(df)
df1
# Out:
#               Player Name Gls Ast CRDY CRDR   CMP   Att  Sh SoT distance FK  \
# 0     Patrick van Aanholt   3   2    0    0  1241  1595  26   5     21.7  3
# 1              Max Aarons   0   1    7    0  1332  1711  14   4     17.2  0
# 2           Tammy Abraham  15   3    2    0   275   418  88  35     11.6  0
# 3               Che Adams   4   2    0    0   162   263  36   9     15.2  0
# 4                  Adrián   0   0    1    0   238   311   0   0           0
# ..                    ...  ..  ..  ...  ...   ...   ...  ..  ..      ... ..
# 517         Wilfried Zaha   4   3    5    0   928  1188  61  17     16.2  0
# 518  Christoph Zimmermann   0   1    3    0   525   664   6   1     16.8  0
# 519   Oleksandr Zinchenko   0   0    2    1  1214  1371  16   3     26.0  0
# 520     Richairo Živković   0   0    0    0    17    19   1   0     11.6  0
# 521            Kurt Zouma   0   0    6    0  1844  2087  15   5     11.4  0
#
# ...

# %%
df=pd.read_csv("2019-2020 player_played.csv")
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#               Player Name  Gls  Ast  CRDY  CRDR   CMP   Att  Sh  SoT  \
# 0     Patrick van Aanholt    3    2     0     0  1241  1595  26    5
# 1              Max Aarons    0    1     7     0  1332  1711  14    4
# 2           Tammy Abraham   15    3     2     0   275   418  88   35
# 3               Che Adams    4    2     0     0   162   263  36    9
# 4                  Adrián    0    0     1     0   238   311   0    0
# ..                    ...  ...  ...   ...   ...   ...   ...  ..  ...
# 517         Wilfried Zaha    4    3     5     0   928  1188  61   17
# 518  Christoph Zimmermann    0    1     3     0   525   664   6    1
# 519   Oleksandr Zinchenko    0    0     2     1  1214  1371  16    3
# 520     Richairo Živković    0    0     0     0    17    19   1    0
# 521            Kurt Zouma    0    0     6     0  1844  2087  15    5
#
#      distance  FK  TKL  Dribbles  Blocks  Touches  Attp  Succ  Carries  \
# ...

# %%
df1['season']='2019-2020'
df1
# Out:
#               Player Name Gls Ast CRDY CRDR   CMP   Att  Sh SoT distance FK  \
# 0     Patrick van Aanholt   3   2    0    0  1241  1595  26   5     21.7  3
# 1              Max Aarons   0   1    7    0  1332  1711  14   4     17.2  0
# 2           Tammy Abraham  15   3    2    0   275   418  88  35     11.6  0
# 3               Che Adams   4   2    0    0   162   263  36   9     15.2  0
# 4                  Adrián   0   0    1    0   238   311   0   0           0
# ..                    ...  ..  ..  ...  ...   ...   ...  ..  ..      ... ..
# 517         Wilfried Zaha   4   3    5    0   928  1188  61  17     16.2  0
# 518  Christoph Zimmermann   0   1    3    0   525   664   6   1     16.8  0
# 519   Oleksandr Zinchenko   0   0    2    1  1214  1371  16   3     26.0  0
# 520     Richairo Živković   0   0    0    0    17    19   1   0     11.6  0
# 521            Kurt Zouma   0   0    6    0  1844  2087  15   5     11.4  0
#
# ...

# %%
df.to_csv("2019-2020 player_played.csv")
